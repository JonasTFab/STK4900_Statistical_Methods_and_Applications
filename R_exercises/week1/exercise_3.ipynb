# %% [markdown]
# Lecture slides at https://www.uio.no/studier/emner/matnat/math/STK4900/v21/lectures/lecture1.pdf
#
# ---------------------------
#
# # Exercise 3: Historical measurements on the speed of light

# %%
data = c(28,-44,29,30,24,28,37,32,36,27,26,28,29,26,28,22,23,20,
         25,25,36,23,31,32,24,27,33,16,24,29,36,21,28,26,27,27,
         26,24,32,29,34,-2,25,19,36,29,30,22,28,33,39,25,16,23)

# %%
hist(data)
# Out:
# Plot with title “Histogram of data”

# %%
plot(ecdf(data), verticals=T, do.points=F)
# Out:
# Plot with title “ecdf(data)”

# %%
boxplot(data)
# Out:
# plot without title

# %% [markdown]
# -2 might look like outliers (two lowest circles in boxplot). -44 might just be opposite directed relative to the intsrument.
